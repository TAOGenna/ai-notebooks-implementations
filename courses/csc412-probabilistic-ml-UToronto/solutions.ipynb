# %%
import numpy as np
from tinygrad.helpers import Timing

# %%
from tinygrad import Tensor

# %%
t1 = Tensor([1,2,3,4,5])
na = np.array([1,2,3,4,5])
t2 = Tensor(na)

# %%
# Out:
# f = 64.0
# df/dx = 64.0
# df/dy = 32.0
